# %% [markdown]
# # Inspect Darknet19 Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import Tensor
from torchinfo import summary
import sys
sys.path.append('../')
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# ## Inspect Structure & In/Out Shape

# %%
from models.darknet19 import Darknet19Config, Darknet19

img_h, img_w, n_class = 224, 224, 1000
model_args = dict(
    img_h=img_h,
    img_w=img_w,
    n_class=n_class
)

model_config = Darknet19Config(**model_args)
model = Darknet19(model_config)

batch_size = 1
summary(model, input_size=[(batch_size, 3, img_h, img_w)], device='cpu',
        col_names=("input_size", "output_size", "num_params", "kernel_size", "mult_adds", "trainable"), verbose=2,
        depth=4, row_settings=("depth", "var_names"));
# Out:
# number of parameters: 20.84M
# ===================================================================================================================================================================================================
# Layer (type (var_name):depth-idx)             Input Shape               Output Shape              Param #                   Kernel Shape              Mult-Adds                 Trainable
# ===================================================================================================================================================================================================
# Darknet19 (Darknet19)                         [1, 3, 224, 224]          [1, 1000]                 --                        --                        --                        True
# ├─Darknet19Backbone (backbone): 1-1           [1, 3, 224, 224]          [1, 1024, 7, 7]           --                        --                        --                        True
# │    └─conv1.conv.weight                                                                          ├─864                     [32, 3, 3, 3]
# │    └─conv1.bn.weight                                                                            ├─32                      [32]
# │    └─conv1.bn.bias                                                                              ├─32                      [32]
# │    └─conv2.conv.weight                                                                          ├─18,432                  [64, 32, 3, 3]
# │    └─conv2.bn.weight                                                                            ├─64                      [64]
# │    └─conv2.bn.bias                                                                              ├─64                      [64]
# │    └─conv3.conv.weight                                                                          ├─73,728                  [128, 64, 3, 3]
# │    └─conv3.bn.weight                                                                            ├─128                     [128]
# │    └─conv3.bn.bias                                                                              ├─128                     [128]
# │    └─conv4.conv.weight                                                                          ├─8,192                   [64, 128, 1, 1]
# │    └─conv4.bn.weight                                                                            ├─64                      [64]
# │    └─conv4.bn.bias                                                                              ├─64                      [64]
# │    └─conv5.conv.weight                                                                          ├─73,728                  [128, 64, 3, 3]
# │    └─conv5.bn.weight                                                                            ├─128                     [128]
# │    └─conv5.bn.bias                                                                              ├─128                     [128]
# │    └─conv6.conv.weight                                                                          ├─294,912                 [256, 128, 3, 3]
# │    └─conv6.bn.weight                                                                            ├─256                     [256]
# │    └─conv6.bn.bias                                                                              ├─256                     [256]
# │    └─conv7.conv.weight                                                                          ├─32,768                  [128, 256, 1, 1]
# │    └─conv7.bn.weight                                                                            ├─128                     [128]
# │    └─conv7.bn.bias                                                                              ├─128                     [128]
# │    └─conv8.conv.weight                                                                          ├─294,912                 [256, 128, 3, 3]
# │    └─conv8.bn.weight                                                                            ├─256                     [256]
# │    └─conv8.bn.bias                                                                              ├─256                     [256]
# │    └─conv9.conv.weight                                                                          ├─1,179,648               [512, 256, 3, 3]
# │    └─conv9.bn.weight                                                                            ├─512                     [512]
# │    └─conv9.bn.bias                                                                              ├─512                     [512]
# │    └─conv10.conv.weight                                                                         ├─131,072                 [256, 512, 1, 1]
# │    └─conv10.bn.weight                                                                           ├─256                     [256]
# │    └─conv10.bn.bias                                                                             ├─256                     [256]
# │    └─conv11.conv.weight                                                                         ├─1,179,648               [512, 256, 3, 3]
# │    └─conv11.bn.weight                                                                           ├─512                     [512]
# │    └─conv11.bn.bias                                                                             ├─512                     [512]
# │    └─conv12.conv.weight                                                                         ├─131,072                 [256, 512, 1, 1]
# │    └─conv12.bn.weight                                                                           ├─256                     [256]
# │    └─conv12.bn.bias                                                                             ├─256                     [256]
# │    └─conv13.conv.weight                                                                         ├─1,179,648               [512, 256, 3, 3]
# │    └─conv13.bn.weight                                                                           ├─512                     [512]
# │    └─conv13.bn.bias                                                                             ├─512                     [512]
# │    └─conv14.conv.weight                                                                         ├─4,718,592               [1024, 512, 3, 3]
# │    └─conv14.bn.weight                                                                           ├─1,024                   [1024]
# │    └─conv14.bn.bias                                                                             ├─1,024                   [1024]
# │    └─conv15.conv.weight                                                                         ├─524,288                 [512, 1024, 1, 1]
# │    └─conv15.bn.weight                                                                           ├─512                     [512]
# │    └─conv15.bn.bias                                                                             ├─512                     [512]
# │    └─conv16.conv.weight                                                                         ├─4,718,592               [1024, 512, 3, 3]
# │    └─conv16.bn.weight                                                                           ├─1,024                   [1024]
# │    └─conv16.bn.bias                                                                             ├─1,024                   [1024]
# │    └─conv17.conv.weight                                                                         ├─524,288                 [512, 1024, 1, 1]
# │    └─conv17.bn.weight                                                                           ├─512                     [512]
# │    └─conv17.bn.bias                                                                             ├─512                     [512]
# │    └─conv18.conv.weight                                                                         ├─4,718,592               [1024, 512, 3, 3]
# │    └─conv18.bn.weight                                                                           ├─1,024                   [1024]
# │    └─conv18.bn.bias                                                                             └─1,024                   [1024]
# │    └─Darknet19Conv2d (conv1): 2-1           [1, 3, 224, 224]          [1, 32, 224, 224]         --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─864                     [32, 3, 3, 3]
# │    │    └─bn.weight                                                                             ├─32                      [32]
# │    │    └─bn.bias                                                                               └─32                      [32]
# │    │    └─Conv2d (conv): 3-1                [1, 3, 224, 224]          [1, 32, 224, 224]         864                       [3, 3]                    43,352,064                True
# │    │    │    └─weight                                                                           └─864                     [3, 32, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-2             [1, 32, 224, 224]         [1, 32, 224, 224]         64                        --                        64                        True
# │    │    │    └─weight                                                                           ├─32                      [32]
# │    │    │    └─bias                                                                             └─32                      [32]
# │    └─MaxPool2d (maxpool1): 2-2              [1, 32, 224, 224]         [1, 32, 112, 112]         --                        2                         --                        --
# │    └─Darknet19Conv2d (conv2): 2-3           [1, 32, 112, 112]         [1, 64, 112, 112]         --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─18,432                  [64, 32, 3, 3]
# │    │    └─bn.weight                                                                             ├─64                      [64]
# │    │    └─bn.bias                                                                               └─64                      [64]
# │    │    └─Conv2d (conv): 3-3                [1, 32, 112, 112]         [1, 64, 112, 112]         18,432                    [3, 3]                    231,211,008               True
# │    │    │    └─weight                                                                           └─18,432                  [32, 64, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-4             [1, 64, 112, 112]         [1, 64, 112, 112]         128                       --                        128                       True
# │    │    │    └─weight                                                                           ├─64                      [64]
# │    │    │    └─bias                                                                             └─64                      [64]
# │    └─MaxPool2d (maxpool2): 2-4              [1, 64, 112, 112]         [1, 64, 56, 56]           --                        2                         --                        --
# │    └─Darknet19Conv2d (conv3): 2-5           [1, 64, 56, 56]           [1, 128, 56, 56]          --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─73,728                  [128, 64, 3, 3]
# │    │    └─bn.weight                                                                             ├─128                     [128]
# │    │    └─bn.bias                                                                               └─128                     [128]
# │    │    └─Conv2d (conv): 3-5                [1, 64, 56, 56]           [1, 128, 56, 56]          73,728                    [3, 3]                    231,211,008               True
# │    │    │    └─weight                                                                           └─73,728                  [64, 128, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-6             [1, 128, 56, 56]          [1, 128, 56, 56]          256                       --                        256                       True
# │    │    │    └─weight                                                                           ├─128                     [128]
# │    │    │    └─bias                                                                             └─128                     [128]
# │    └─Darknet19Conv2d (conv4): 2-6           [1, 128, 56, 56]          [1, 64, 56, 56]           --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─8,192                   [64, 128, 1, 1]
# │    │    └─bn.weight                                                                             ├─64                      [64]
# │    │    └─bn.bias                                                                               └─64                      [64]
# │    │    └─Conv2d (conv): 3-7                [1, 128, 56, 56]          [1, 64, 56, 56]           8,192                     [1, 1]                    25,690,112                True
# │    │    │    └─weight                                                                           └─8,192                   [128, 64, 1, 1]
# │    │    └─BatchNorm2d (bn): 3-8             [1, 64, 56, 56]           [1, 64, 56, 56]           128                       --                        128                       True
# │    │    │    └─weight                                                                           ├─64                      [64]
# │    │    │    └─bias                                                                             └─64                      [64]
# │    └─Darknet19Conv2d (conv5): 2-7           [1, 64, 56, 56]           [1, 128, 56, 56]          --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─73,728                  [128, 64, 3, 3]
# │    │    └─bn.weight                                                                             ├─128                     [128]
# │    │    └─bn.bias                                                                               └─128                     [128]
# │    │    └─Conv2d (conv): 3-9                [1, 64, 56, 56]           [1, 128, 56, 56]          73,728                    [3, 3]                    231,211,008               True
# │    │    │    └─weight                                                                           └─73,728                  [64, 128, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-10            [1, 128, 56, 56]          [1, 128, 56, 56]          256                       --                        256                       True
# │    │    │    └─weight                                                                           ├─128                     [128]
# │    │    │    └─bias                                                                             └─128                     [128]
# │    └─MaxPool2d (maxpool3): 2-8              [1, 128, 56, 56]          [1, 128, 28, 28]          --                        2                         --                        --
# │    └─Darknet19Conv2d (conv6): 2-9           [1, 128, 28, 28]          [1, 256, 28, 28]          --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─294,912                 [256, 128, 3, 3]
# │    │    └─bn.weight                                                                             ├─256                     [256]
# │    │    └─bn.bias                                                                               └─256                     [256]
# │    │    └─Conv2d (conv): 3-11               [1, 128, 28, 28]          [1, 256, 28, 28]          294,912                   [3, 3]                    231,211,008               True
# │    │    │    └─weight                                                                           └─294,912                 [128, 256, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-12            [1, 256, 28, 28]          [1, 256, 28, 28]          512                       --                        512                       True
# │    │    │    └─weight                                                                           ├─256                     [256]
# │    │    │    └─bias                                                                             └─256                     [256]
# │    └─Darknet19Conv2d (conv7): 2-10          [1, 256, 28, 28]          [1, 128, 28, 28]          --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─32,768                  [128, 256, 1, 1]
# │    │    └─bn.weight                                                                             ├─128                     [128]
# │    │    └─bn.bias                                                                               └─128                     [128]
# │    │    └─Conv2d (conv): 3-13               [1, 256, 28, 28]          [1, 128, 28, 28]          32,768                    [1, 1]                    25,690,112                True
# │    │    │    └─weight                                                                           └─32,768                  [256, 128, 1, 1]
# │    │    └─BatchNorm2d (bn): 3-14            [1, 128, 28, 28]          [1, 128, 28, 28]          256                       --                        256                       True
# │    │    │    └─weight                                                                           ├─128                     [128]
# │    │    │    └─bias                                                                             └─128                     [128]
# │    └─Darknet19Conv2d (conv8): 2-11          [1, 128, 28, 28]          [1, 256, 28, 28]          --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─294,912                 [256, 128, 3, 3]
# │    │    └─bn.weight                                                                             ├─256                     [256]
# │    │    └─bn.bias                                                                               └─256                     [256]
# │    │    └─Conv2d (conv): 3-15               [1, 128, 28, 28]          [1, 256, 28, 28]          294,912                   [3, 3]                    231,211,008               True
# │    │    │    └─weight                                                                           └─294,912                 [128, 256, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-16            [1, 256, 28, 28]          [1, 256, 28, 28]          512                       --                        512                       True
# │    │    │    └─weight                                                                           ├─256                     [256]
# │    │    │    └─bias                                                                             └─256                     [256]
# │    └─MaxPool2d (maxpool4): 2-12             [1, 256, 28, 28]          [1, 256, 14, 14]          --                        2                         --                        --
# │    └─Darknet19Conv2d (conv9): 2-13          [1, 256, 14, 14]          [1, 512, 14, 14]          --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─1,179,648               [512, 256, 3, 3]
# │    │    └─bn.weight                                                                             ├─512                     [512]
# │    │    └─bn.bias                                                                               └─512                     [512]
# │    │    └─Conv2d (conv): 3-17               [1, 256, 14, 14]          [1, 512, 14, 14]          1,179,648                 [3, 3]                    231,211,008               True
# │    │    │    └─weight                                                                           └─1,179,648               [256, 512, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-18            [1, 512, 14, 14]          [1, 512, 14, 14]          1,024                     --                        1,024                     True
# │    │    │    └─weight                                                                           ├─512                     [512]
# │    │    │    └─bias                                                                             └─512                     [512]
# │    └─Darknet19Conv2d (conv10): 2-14         [1, 512, 14, 14]          [1, 256, 14, 14]          --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─131,072                 [256, 512, 1, 1]
# │    │    └─bn.weight                                                                             ├─256                     [256]
# │    │    └─bn.bias                                                                               └─256                     [256]
# │    │    └─Conv2d (conv): 3-19               [1, 512, 14, 14]          [1, 256, 14, 14]          131,072                   [1, 1]                    25,690,112                True
# │    │    │    └─weight                                                                           └─131,072                 [512, 256, 1, 1]
# │    │    └─BatchNorm2d (bn): 3-20            [1, 256, 14, 14]          [1, 256, 14, 14]          512                       --                        512                       True
# │    │    │    └─weight                                                                           ├─256                     [256]
# │    │    │    └─bias                                                                             └─256                     [256]
# │    └─Darknet19Conv2d (conv11): 2-15         [1, 256, 14, 14]          [1, 512, 14, 14]          --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─1,179,648               [512, 256, 3, 3]
# │    │    └─bn.weight                                                                             ├─512                     [512]
# │    │    └─bn.bias                                                                               └─512                     [512]
# │    │    └─Conv2d (conv): 3-21               [1, 256, 14, 14]          [1, 512, 14, 14]          1,179,648                 [3, 3]                    231,211,008               True
# │    │    │    └─weight                                                                           └─1,179,648               [256, 512, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-22            [1, 512, 14, 14]          [1, 512, 14, 14]          1,024                     --                        1,024                     True
# │    │    │    └─weight                                                                           ├─512                     [512]
# │    │    │    └─bias                                                                             └─512                     [512]
# │    └─Darknet19Conv2d (conv12): 2-16         [1, 512, 14, 14]          [1, 256, 14, 14]          --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─131,072                 [256, 512, 1, 1]
# │    │    └─bn.weight                                                                             ├─256                     [256]
# │    │    └─bn.bias                                                                               └─256                     [256]
# │    │    └─Conv2d (conv): 3-23               [1, 512, 14, 14]          [1, 256, 14, 14]          131,072                   [1, 1]                    25,690,112                True
# │    │    │    └─weight                                                                           └─131,072                 [512, 256, 1, 1]
# │    │    └─BatchNorm2d (bn): 3-24            [1, 256, 14, 14]          [1, 256, 14, 14]          512                       --                        512                       True
# │    │    │    └─weight                                                                           ├─256                     [256]
# │    │    │    └─bias                                                                             └─256                     [256]
# │    └─Darknet19Conv2d (conv13): 2-17         [1, 256, 14, 14]          [1, 512, 14, 14]          --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─1,179,648               [512, 256, 3, 3]
# │    │    └─bn.weight                                                                             ├─512                     [512]
# │    │    └─bn.bias                                                                               └─512                     [512]
# │    │    └─Conv2d (conv): 3-25               [1, 256, 14, 14]          [1, 512, 14, 14]          1,179,648                 [3, 3]                    231,211,008               True
# │    │    │    └─weight                                                                           └─1,179,648               [256, 512, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-26            [1, 512, 14, 14]          [1, 512, 14, 14]          1,024                     --                        1,024                     True
# │    │    │    └─weight                                                                           ├─512                     [512]
# │    │    │    └─bias                                                                             └─512                     [512]
# │    └─MaxPool2d (maxpool5): 2-18             [1, 512, 14, 14]          [1, 512, 7, 7]            --                        2                         --                        --
# │    └─Darknet19Conv2d (conv14): 2-19         [1, 512, 7, 7]            [1, 1024, 7, 7]           --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─4,718,592               [1024, 512, 3, 3]
# │    │    └─bn.weight                                                                             ├─1,024                   [1024]
# │    │    └─bn.bias                                                                               └─1,024                   [1024]
# │    │    └─Conv2d (conv): 3-27               [1, 512, 7, 7]            [1, 1024, 7, 7]           4,718,592                 [3, 3]                    231,211,008               True
# │    │    │    └─weight                                                                           └─4,718,592               [512, 1024, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-28            [1, 1024, 7, 7]           [1, 1024, 7, 7]           2,048                     --                        2,048                     True
# │    │    │    └─weight                                                                           ├─1,024                   [1024]
# │    │    │    └─bias                                                                             └─1,024                   [1024]
# │    └─Darknet19Conv2d (conv15): 2-20         [1, 1024, 7, 7]           [1, 512, 7, 7]            --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─524,288                 [512, 1024, 1, 1]
# │    │    └─bn.weight                                                                             ├─512                     [512]
# │    │    └─bn.bias                                                                               └─512                     [512]
# │    │    └─Conv2d (conv): 3-29               [1, 1024, 7, 7]           [1, 512, 7, 7]            524,288                   [1, 1]                    25,690,112                True
# │    │    │    └─weight                                                                           └─524,288                 [1024, 512, 1, 1]
# │    │    └─BatchNorm2d (bn): 3-30            [1, 512, 7, 7]            [1, 512, 7, 7]            1,024                     --                        1,024                     True
# │    │    │    └─weight                                                                           ├─512                     [512]
# │    │    │    └─bias                                                                             └─512                     [512]
# │    └─Darknet19Conv2d (conv16): 2-21         [1, 512, 7, 7]            [1, 1024, 7, 7]           --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─4,718,592               [1024, 512, 3, 3]
# │    │    └─bn.weight                                                                             ├─1,024                   [1024]
# │    │    └─bn.bias                                                                               └─1,024                   [1024]
# │    │    └─Conv2d (conv): 3-31               [1, 512, 7, 7]            [1, 1024, 7, 7]           4,718,592                 [3, 3]                    231,211,008               True
# │    │    │    └─weight                                                                           └─4,718,592               [512, 1024, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-32            [1, 1024, 7, 7]           [1, 1024, 7, 7]           2,048                     --                        2,048                     True
# │    │    │    └─weight                                                                           ├─1,024                   [1024]
# │    │    │    └─bias                                                                             └─1,024                   [1024]
# │    └─Darknet19Conv2d (conv17): 2-22         [1, 1024, 7, 7]           [1, 512, 7, 7]            --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─524,288                 [512, 1024, 1, 1]
# │    │    └─bn.weight                                                                             ├─512                     [512]
# │    │    └─bn.bias                                                                               └─512                     [512]
# │    │    └─Conv2d (conv): 3-33               [1, 1024, 7, 7]           [1, 512, 7, 7]            524,288                   [1, 1]                    25,690,112                True
# │    │    │    └─weight                                                                           └─524,288                 [1024, 512, 1, 1]
# │    │    └─BatchNorm2d (bn): 3-34            [1, 512, 7, 7]            [1, 512, 7, 7]            1,024                     --                        1,024                     True
# │    │    │    └─weight                                                                           ├─512                     [512]
# │    │    │    └─bias                                                                             └─512                     [512]
# │    └─Darknet19Conv2d (conv18): 2-23         [1, 512, 7, 7]            [1, 1024, 7, 7]           --                        --                        --                        True
# │    │    └─conv.weight                                                                           ├─4,718,592               [1024, 512, 3, 3]
# │    │    └─bn.weight                                                                             ├─1,024                   [1024]
# │    │    └─bn.bias                                                                               └─1,024                   [1024]
# │    │    └─Conv2d (conv): 3-35               [1, 512, 7, 7]            [1, 1024, 7, 7]           4,718,592                 [3, 3]                    231,211,008               True
# │    │    │    └─weight                                                                           └─4,718,592               [512, 1024, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-36            [1, 1024, 7, 7]           [1, 1024, 7, 7]           2,048                     --                        2,048                     True
# │    │    │    └─weight                                                                           ├─1,024                   [1024]
# │    │    │    └─bias                                                                             └─1,024                   [1024]
# ├─Sequential (head): 1-2                      [1, 1024, 7, 7]           [1, 1000]                 --                        --                        --                        True
# │    └─0.weight                                                                                   ├─1,024,000               [1000, 1024, 1, 1]
# │    └─0.bias                                                                                     └─1,000                   [1000]
# │    └─Conv2d (0): 2-24                       [1, 1024, 7, 7]           [1, 1000, 7, 7]           1,025,000                 [1, 1]                    50,225,000                True
# │    │    └─weight                                                                                ├─1,024,000               [1024, 1000, 1, 1]
# │    │    └─bias                                                                                  └─1,000                   [1000]
# │    └─AdaptiveAvgPool2d (1): 2-25            [1, 1000, 7, 7]           [1, 1000, 1, 1]           --                        --                        --                        --
# │    └─Flatten (2): 2-26                      [1, 1000, 1, 1]           [1, 1000]                 --                        --                        --                        --
# ===================================================================================================================================================================================================
# Total params: 20,842,376
# Trainable params: 20,842,376
# Non-trainable params: 0
# Total mult-adds (G): 2.79
# ===================================================================================================================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 72.65
# Params size (MB): 83.37
# Estimated Total Size (MB): 156.62
# ===================================================================================================================================================================================================

# %%
writer = SummaryWriter()
imgs = torch.randn(batch_size, 3, img_h, img_w)
targets = torch.randint(0, n_class, (batch_size,))
writer.add_graph(model, [imgs, targets])
writer.close()

# %%
logits, loss = model(imgs, targets)
print(logits.shape)
print(loss.shape)
# Out:
# torch.Size([1, 1000])
# torch.Size([])

# %% [markdown]
# ## Inspect state_dict

# %%
import tempfile

# Save state_dict as a temporary file
with tempfile.NamedTemporaryFile(suffix='.pth') as temp_file:
    torch.save(model.state_dict(), temp_file.name)
    state_dict = torch.load(temp_file.name)

# Print the keys of the state_dict
for key in state_dict.keys():
    print(key)
# Out:
# backbone.conv1.conv.weight
# backbone.conv1.bn.weight
# backbone.conv1.bn.bias
# backbone.conv1.bn.running_mean
# backbone.conv1.bn.running_var
# backbone.conv1.bn.num_batches_tracked
# backbone.conv2.conv.weight
# backbone.conv2.bn.weight
# backbone.conv2.bn.bias
# backbone.conv2.bn.running_mean
# backbone.conv2.bn.running_var
# backbone.conv2.bn.num_batches_tracked
# backbone.conv3.conv.weight
# backbone.conv3.bn.weight
# backbone.conv3.bn.bias
# backbone.conv3.bn.running_mean
# backbone.conv3.bn.running_var
# backbone.conv3.bn.num_batches_tracked
# backbone.conv4.conv.weight
# backbone.conv4.bn.weight
# backbone.conv4.bn.bias
# backbone.conv4.bn.running_mean
# backbone.conv4.bn.running_var
# backbone.conv4.bn.num_batches_tracked
# backbone.conv5.conv.weight
# backbone.conv5.bn.weight
# backbone.conv5.bn.bias
# backbone.conv5.bn.running_mean
# backbone.conv5.bn.running_var
# backbone.conv5.bn.num_batches_tracked
# backbone.conv6.conv.weight
# backbone.conv6.bn.weight
# backbone.conv6.bn.bias
# backbone.conv6.bn.running_mean
# backbone.conv6.bn.running_var
# backbone.conv6.bn.num_batches_tracked
# backbone.conv7.conv.weight
# backbone.conv7.bn.weight
# backbone.conv7.bn.bias
# backbone.conv7.bn.running_mean
# backbone.conv7.bn.running_var
# backbone.conv7.bn.num_batches_tracked
# backbone.conv8.conv.weight
# backbone.conv8.bn.weight
# backbone.conv8.bn.bias
# backbone.conv8.bn.running_mean
# backbone.conv8.bn.running_var
# backbone.conv8.bn.num_batches_tracked
# backbone.conv9.conv.weight
# backbone.conv9.bn.weight
# backbone.conv9.bn.bias
# backbone.conv9.bn.running_mean
# backbone.conv9.bn.running_var
# backbone.conv9.bn.num_batches_tracked
# backbone.conv10.conv.weight
# backbone.conv10.bn.weight
# backbone.conv10.bn.bias
# backbone.conv10.bn.running_mean
# backbone.conv10.bn.running_var
# backbone.conv10.bn.num_batches_tracked
# backbone.conv11.conv.weight
# backbone.conv11.bn.weight
# backbone.conv11.bn.bias
# backbone.conv11.bn.running_mean
# backbone.conv11.bn.running_var
# backbone.conv11.bn.num_batches_tracked
# backbone.conv12.conv.weight
# backbone.conv12.bn.weight
# backbone.conv12.bn.bias
# backbone.conv12.bn.running_mean
# backbone.conv12.bn.running_var
# backbone.conv12.bn.num_batches_tracked
# backbone.conv13.conv.weight
# backbone.conv13.bn.weight
# backbone.conv13.bn.bias
# backbone.conv13.bn.running_mean
# backbone.conv13.bn.running_var
# backbone.conv13.bn.num_batches_tracked
# backbone.conv14.conv.weight
# backbone.conv14.bn.weight
# backbone.conv14.bn.bias
# backbone.conv14.bn.running_mean
# backbone.conv14.bn.running_var
# backbone.conv14.bn.num_batches_tracked
# backbone.conv15.conv.weight
# backbone.conv15.bn.weight
# backbone.conv15.bn.bias
# backbone.conv15.bn.running_mean
# backbone.conv15.bn.running_var
# backbone.conv15.bn.num_batches_tracked
# backbone.conv16.conv.weight
# backbone.conv16.bn.weight
# backbone.conv16.bn.bias
# backbone.conv16.bn.running_mean
# backbone.conv16.bn.running_var
# backbone.conv16.bn.num_batches_tracked
# backbone.conv17.conv.weight
# backbone.conv17.bn.weight
# backbone.conv17.bn.bias
# backbone.conv17.bn.running_mean
# backbone.conv17.bn.running_var
# backbone.conv17.bn.num_batches_tracked
# backbone.conv18.conv.weight
# backbone.conv18.bn.weight
# backbone.conv18.bn.bias
# backbone.conv18.bn.running_mean
# backbone.conv18.bn.running_var
# backbone.conv18.bn.num_batches_tracked
# head.0.weight
# head.0.bias

# %% [markdown]
# ## Inspec gradients

# %%
class DebugDependencyDarknet19(Darknet19):
    """Darknet19 with dummy loss function for debugging dependencies."""
    def __init__(self, loss_img_idx, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.loss_img_idx = loss_img_idx

    def _compute_loss(self, logits: Tensor, targets: Tensor) -> Tensor:
        """
        Compute the dummy loss as sum of all outputs of img i.
        Args:
            logits (Tensor): size(N, n_class)
            targets (Tensor): size(N,)
        Returns:
            loss (Tensor): size(,)
        """
        return torch.sum(logits[self.loss_img_idx])

# %% [markdown]
# To verify no inadvertently mix information across the batch dimension, run the backward pass all the way to the input, and ensure that you get a non-zero gradient only on the i-th input.

# %%
batch_size = 5
X = torch.randn(batch_size, 3, img_h, img_w, requires_grad=True)
Y =  torch.randint(0, n_class, (batch_size,))

# %%
print("Setup:")
torch.manual_seed(1337);  # since kaiming_normal_ weight init is random
loss_img_idx = 2
debug_dependency_model = DebugDependencyDarknet19(loss_img_idx, model_config)
debug_dependency_model.eval()  # since batchnorm will mixed variables between images in a batch

optimizer_type = 'adam'
learning_rate = 3e-4
beta1 = 0.9
beta2 = 0.999
weight_decay = 5e-4
device_type = 'cpu'
use_fused = False
optimizer = debug_dependency_model.configure_optimizers(optimizer_type, learning_rate, (beta1, beta2), weight_decay, device_type, use_fused)

print("\n\nForward pass:")
logits, loss = debug_dependency_model(X, Y)
print(f"{logits.shape=}")
print(f"{loss=}")

print("\n\nBackward pass & Gradients of X::")
optimizer.zero_grad(set_to_none=True)
X.grad = None  # zero out X gradients
loss.backward()

print(f"{X.grad.shape=}")
for idx_img in range(batch_size):
    print(f"Zero gradient of {idx_img}'th img: {torch.all(X.grad[idx_img]==0)}")

print("\n\nOptimizer step:")
optimizer.step()
print(f"Loss after optimized: {debug_dependency_model(X, Y)[1]}")
# Out:
# Setup:
# number of parameters: 20.84M
# num decayed parameter tensors: 19, with 20,826,976 parameters
# num non-decayed parameter tensors: 37, with 15,400 parameters
# using fused Adam: False
#
#
# Forward pass:
# logits.shape=torch.Size([5, 1000])
# loss=tensor(9.1461, grad_fn=<SumBackward0>)
#
#
# Backward pass & Gradients of X::
# X.grad.shape=torch.Size([5, 3, 224, 224])
# Zero gradient of 0'th img: True
# Zero gradient of 1'th img: True
# Zero gradient of 2'th img: False
# Zero gradient of 3'th img: True
# Zero gradient of 4'th img: True
#
#
# Optimizer step:
# Loss after optimized: -259.7261047363281

# %% [markdown]
# ## Extract Features

# %%
from torchvision.models.feature_extraction import get_graph_node_names
from torchvision.models.feature_extraction import create_feature_extractor
from models.darknet19 import Darknet19Config, Darknet19Backbone

img_h, img_w = 416, 416
backbone = Darknet19Backbone(Darknet19Config(img_h=img_h, img_w=img_w))

# %%
train_nodes, eval_nodes = get_graph_node_names(backbone)
print(f"{train_nodes=}")
print(f"{eval_nodes=}")
# Out:
# train_nodes=['x', 'conv1.conv', 'conv1.bn', 'conv1.leaky_relu', 'maxpool1', 'conv2.conv', 'conv2.bn', 'conv2.leaky_relu', 'maxpool2', 'conv3.conv', 'conv3.bn', 'conv3.leaky_relu', 'conv4.conv', 'conv4.bn', 'conv4.leaky_relu', 'conv5.conv', 'conv5.bn', 'conv5.leaky_relu', 'maxpool3', 'conv6.conv', 'conv6.bn', 'conv6.leaky_relu', 'conv7.conv', 'conv7.bn', 'conv7.leaky_relu', 'conv8.conv', 'conv8.bn', 'conv8.leaky_relu', 'maxpool4', 'conv9.conv', 'conv9.bn', 'conv9.leaky_relu', 'conv10.conv', 'conv10.bn', 'conv10.leaky_relu', 'conv11.conv', 'conv11.bn', 'conv11.leaky_relu', 'conv12.conv', 'conv12.bn', 'conv12.leaky_relu', 'conv13.conv', 'conv13.bn', 'conv13.leaky_relu', 'maxpool5', 'conv14.conv', 'conv14.bn', 'conv14.leaky_relu', 'conv15.conv', 'conv15.bn', 'conv15.leaky_relu', 'conv16.conv', 'conv16.bn', 'conv16.leaky_relu', 'conv17.conv', 'conv17.bn', 'conv17.leaky_relu', 'conv18.conv', 'conv18.bn', 'conv18.leaky_relu']
# eval_nodes=['x', 'conv1.conv', 'conv1.bn', 'conv1.leaky_relu', 'maxpool1', 'conv2.conv', 'conv2.bn', 'conv2.leaky_relu', 'maxpool2', 'conv3.conv', 'conv3.bn', 'conv3.leaky_relu', 'conv4.conv', 'conv4.bn', 'conv4.leaky_relu', 'conv5.conv', 'conv5.bn', 'conv5.leaky_relu', 'maxpool3', 'conv6.conv', 'conv6.bn', 'conv6.leaky_relu', 'conv7.conv', 'conv7.bn', 'conv7.leaky_relu', 'conv8.conv', 'conv8.bn', 'conv8.leaky_relu', 'maxpool4', 'conv9.conv', 'conv9.bn', 'conv9.leaky_relu', 'conv10.conv', 'conv10.bn', 'conv10.leaky_relu', 'conv11.conv', 'conv11.bn', 'conv11.leaky_relu', 'conv12.conv', 'conv12.bn', 'conv12.leaky_relu', 'conv13.conv', 'conv13.bn', 'conv13.leaky_relu', 'maxpool5', 'conv14.conv', 'conv14.bn', 'conv14.leaky_relu', 'conv15.conv', 'conv15.bn', 'conv15.leaky_relu', 'conv16.conv', 'conv16.bn', 'conv16.leaky_relu', 'conv17.conv', 'conv17.bn', 'conv17.leaky_relu', 'conv18.conv', 'conv18.bn', 'conv18.leaky_relu']
# /home/alvin/miniconda3/envs/yolo/lib/python3.10/site-packages/torch/overrides.py:110: UserWarning: 'has_cuda' is deprecated, please use 'torch.backends.cuda.is_built()'
#   torch.has_cuda,
# /home/alvin/miniconda3/envs/yolo/lib/python3.10/site-packages/torch/overrides.py:111: UserWarning: 'has_cudnn' is deprecated, please use 'torch.backends.cudnn.is_available()'
#   torch.has_cudnn,
# /home/alvin/miniconda3/envs/yolo/lib/python3.10/site-packages/torch/overrides.py:117: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   torch.has_mps,
# /home/alvin/miniconda3/envs/yolo/lib/python3.10/site-packages/torch/overrides.py:118: UserWarning: 'has_mkldnn' is deprecated, please use 'torch.backends.mkldnn.is_available()'
#   torch.has_mkldnn,

# %%
backbone_with_feat = create_feature_extractor(backbone,
                                              return_nodes={'conv13': 'conv13',
                                                            'conv18': 'conv18',})
imgs = torch.randn(1, 3, img_h, img_w)
feat = backbone_with_feat(imgs)
print(f"{feat.keys()=}")
print(f"{feat['conv13'].shape=}")
print(f"{feat['conv18'].shape=}")
# Out:
# feat.keys()=dict_keys(['conv13', 'conv18'])
# feat['conv13'].shape=torch.Size([1, 512, 26, 26])
# feat['conv18'].shape=torch.Size([1, 1024, 13, 13])

# %%
batch_size = 1
summary(backbone_with_feat, input_size=[(batch_size, 3, img_h, img_w)], device='cpu',
        col_names=("input_size", "output_size", "num_params", "kernel_size", "mult_adds", "trainable"), verbose=2,
        depth=4, row_settings=("depth", "var_names"));
# Out:
# ==============================================================================================================================================================================================
# Layer (type (var_name):depth-idx)        Input Shape               Output Shape              Param #                   Kernel Shape              Mult-Adds                 Trainable
# ==============================================================================================================================================================================================
# Darknet19Backbone (Darknet19Backbone)    [1, 3, 416, 416]          [1, 1024, 13, 13]         --                        --                        --                        True
# ├─Module (conv1): 1-1                    --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─864                     [32, 3, 3, 3]
# │    └─bn.weight                                                                             ├─32                      [32]
# │    └─bn.bias                                                                               └─32                      [32]
# │    └─Conv2d (conv): 2-1                [1, 3, 416, 416]          [1, 32, 416, 416]         864                       [3, 3]                    149,520,384               True
# │    │    └─weight                                                                           └─864                     [3, 32, 3, 3]
# │    └─BatchNorm2d (bn): 2-2             [1, 32, 416, 416]         [1, 32, 416, 416]         64                        --                        64                        True
# │    │    └─weight                                                                           ├─32                      [32]
# │    │    └─bias                                                                             └─32                      [32]
# ├─MaxPool2d (maxpool1): 1-2              [1, 32, 416, 416]         [1, 32, 208, 208]         --                        2                         --                        --
# ├─Module (conv2): 1-3                    --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─18,432                  [64, 32, 3, 3]
# │    └─bn.weight                                                                             ├─64                      [64]
# │    └─bn.bias                                                                               └─64                      [64]
# │    └─Conv2d (conv): 2-3                [1, 32, 208, 208]         [1, 64, 208, 208]         18,432                    [3, 3]                    797,442,048               True
# │    │    └─weight                                                                           └─18,432                  [32, 64, 3, 3]
# │    └─BatchNorm2d (bn): 2-4             [1, 64, 208, 208]         [1, 64, 208, 208]         128                       --                        128                       True
# │    │    └─weight                                                                           ├─64                      [64]
# │    │    └─bias                                                                             └─64                      [64]
# ├─MaxPool2d (maxpool2): 1-4              [1, 64, 208, 208]         [1, 64, 104, 104]         --                        2                         --                        --
# ├─Module (conv3): 1-5                    --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─73,728                  [128, 64, 3, 3]
# │    └─bn.weight                                                                             ├─128                     [128]
# │    └─bn.bias                                                                               └─128                     [128]
# │    └─Conv2d (conv): 2-5                [1, 64, 104, 104]         [1, 128, 104, 104]        73,728                    [3, 3]                    797,442,048               True
# │    │    └─weight                                                                           └─73,728                  [64, 128, 3, 3]
# │    └─BatchNorm2d (bn): 2-6             [1, 128, 104, 104]        [1, 128, 104, 104]        256                       --                        256                       True
# │    │    └─weight                                                                           ├─128                     [128]
# │    │    └─bias                                                                             └─128                     [128]
# ├─Module (conv4): 1-6                    --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─8,192                   [64, 128, 1, 1]
# │    └─bn.weight                                                                             ├─64                      [64]
# │    └─bn.bias                                                                               └─64                      [64]
# │    └─Conv2d (conv): 2-7                [1, 128, 104, 104]        [1, 64, 104, 104]         8,192                     [1, 1]                    88,604,672                True
# │    │    └─weight                                                                           └─8,192                   [128, 64, 1, 1]
# │    └─BatchNorm2d (bn): 2-8             [1, 64, 104, 104]         [1, 64, 104, 104]         128                       --                        128                       True
# │    │    └─weight                                                                           ├─64                      [64]
# │    │    └─bias                                                                             └─64                      [64]
# ├─Module (conv5): 1-7                    --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─73,728                  [128, 64, 3, 3]
# │    └─bn.weight                                                                             ├─128                     [128]
# │    └─bn.bias                                                                               └─128                     [128]
# │    └─Conv2d (conv): 2-9                [1, 64, 104, 104]         [1, 128, 104, 104]        73,728                    [3, 3]                    797,442,048               True
# │    │    └─weight                                                                           └─73,728                  [64, 128, 3, 3]
# │    └─BatchNorm2d (bn): 2-10            [1, 128, 104, 104]        [1, 128, 104, 104]        256                       --                        256                       True
# │    │    └─weight                                                                           ├─128                     [128]
# │    │    └─bias                                                                             └─128                     [128]
# ├─MaxPool2d (maxpool3): 1-8              [1, 128, 104, 104]        [1, 128, 52, 52]          --                        2                         --                        --
# ├─Module (conv6): 1-9                    --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─294,912                 [256, 128, 3, 3]
# │    └─bn.weight                                                                             ├─256                     [256]
# │    └─bn.bias                                                                               └─256                     [256]
# │    └─Conv2d (conv): 2-11               [1, 128, 52, 52]          [1, 256, 52, 52]          294,912                   [3, 3]                    797,442,048               True
# │    │    └─weight                                                                           └─294,912                 [128, 256, 3, 3]
# │    └─BatchNorm2d (bn): 2-12            [1, 256, 52, 52]          [1, 256, 52, 52]          512                       --                        512                       True
# │    │    └─weight                                                                           ├─256                     [256]
# │    │    └─bias                                                                             └─256                     [256]
# ├─Module (conv7): 1-10                   --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─32,768                  [128, 256, 1, 1]
# │    └─bn.weight                                                                             ├─128                     [128]
# │    └─bn.bias                                                                               └─128                     [128]
# │    └─Conv2d (conv): 2-13               [1, 256, 52, 52]          [1, 128, 52, 52]          32,768                    [1, 1]                    88,604,672                True
# │    │    └─weight                                                                           └─32,768                  [256, 128, 1, 1]
# │    └─BatchNorm2d (bn): 2-14            [1, 128, 52, 52]          [1, 128, 52, 52]          256                       --                        256                       True
# │    │    └─weight                                                                           ├─128                     [128]
# │    │    └─bias                                                                             └─128                     [128]
# ├─Module (conv8): 1-11                   --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─294,912                 [256, 128, 3, 3]
# │    └─bn.weight                                                                             ├─256                     [256]
# │    └─bn.bias                                                                               └─256                     [256]
# │    └─Conv2d (conv): 2-15               [1, 128, 52, 52]          [1, 256, 52, 52]          294,912                   [3, 3]                    797,442,048               True
# │    │    └─weight                                                                           └─294,912                 [128, 256, 3, 3]
# │    └─BatchNorm2d (bn): 2-16            [1, 256, 52, 52]          [1, 256, 52, 52]          512                       --                        512                       True
# │    │    └─weight                                                                           ├─256                     [256]
# │    │    └─bias                                                                             └─256                     [256]
# ├─MaxPool2d (maxpool4): 1-12             [1, 256, 52, 52]          [1, 256, 26, 26]          --                        2                         --                        --
# ├─Module (conv9): 1-13                   --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─1,179,648               [512, 256, 3, 3]
# │    └─bn.weight                                                                             ├─512                     [512]
# │    └─bn.bias                                                                               └─512                     [512]
# │    └─Conv2d (conv): 2-17               [1, 256, 26, 26]          [1, 512, 26, 26]          1,179,648                 [3, 3]                    797,442,048               True
# │    │    └─weight                                                                           └─1,179,648               [256, 512, 3, 3]
# │    └─BatchNorm2d (bn): 2-18            [1, 512, 26, 26]          [1, 512, 26, 26]          1,024                     --                        1,024                     True
# │    │    └─weight                                                                           ├─512                     [512]
# │    │    └─bias                                                                             └─512                     [512]
# ├─Module (conv10): 1-14                  --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─131,072                 [256, 512, 1, 1]
# │    └─bn.weight                                                                             ├─256                     [256]
# │    └─bn.bias                                                                               └─256                     [256]
# │    └─Conv2d (conv): 2-19               [1, 512, 26, 26]          [1, 256, 26, 26]          131,072                   [1, 1]                    88,604,672                True
# │    │    └─weight                                                                           └─131,072                 [512, 256, 1, 1]
# │    └─BatchNorm2d (bn): 2-20            [1, 256, 26, 26]          [1, 256, 26, 26]          512                       --                        512                       True
# │    │    └─weight                                                                           ├─256                     [256]
# │    │    └─bias                                                                             └─256                     [256]
# ├─Module (conv11): 1-15                  --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─1,179,648               [512, 256, 3, 3]
# │    └─bn.weight                                                                             ├─512                     [512]
# │    └─bn.bias                                                                               └─512                     [512]
# │    └─Conv2d (conv): 2-21               [1, 256, 26, 26]          [1, 512, 26, 26]          1,179,648                 [3, 3]                    797,442,048               True
# │    │    └─weight                                                                           └─1,179,648               [256, 512, 3, 3]
# │    └─BatchNorm2d (bn): 2-22            [1, 512, 26, 26]          [1, 512, 26, 26]          1,024                     --                        1,024                     True
# │    │    └─weight                                                                           ├─512                     [512]
# │    │    └─bias                                                                             └─512                     [512]
# ├─Module (conv12): 1-16                  --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─131,072                 [256, 512, 1, 1]
# │    └─bn.weight                                                                             ├─256                     [256]
# │    └─bn.bias                                                                               └─256                     [256]
# │    └─Conv2d (conv): 2-23               [1, 512, 26, 26]          [1, 256, 26, 26]          131,072                   [1, 1]                    88,604,672                True
# │    │    └─weight                                                                           └─131,072                 [512, 256, 1, 1]
# │    └─BatchNorm2d (bn): 2-24            [1, 256, 26, 26]          [1, 256, 26, 26]          512                       --                        512                       True
# │    │    └─weight                                                                           ├─256                     [256]
# │    │    └─bias                                                                             └─256                     [256]
# ├─Module (conv13): 1-17                  --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─1,179,648               [512, 256, 3, 3]
# │    └─bn.weight                                                                             ├─512                     [512]
# │    └─bn.bias                                                                               └─512                     [512]
# │    └─Conv2d (conv): 2-25               [1, 256, 26, 26]          [1, 512, 26, 26]          1,179,648                 [3, 3]                    797,442,048               True
# │    │    └─weight                                                                           └─1,179,648               [256, 512, 3, 3]
# │    └─BatchNorm2d (bn): 2-26            [1, 512, 26, 26]          [1, 512, 26, 26]          1,024                     --                        1,024                     True
# │    │    └─weight                                                                           ├─512                     [512]
# │    │    └─bias                                                                             └─512                     [512]
# ├─MaxPool2d (maxpool5): 1-18             [1, 512, 26, 26]          [1, 512, 13, 13]          --                        2                         --                        --
# ├─Module (conv14): 1-19                  --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─4,718,592               [1024, 512, 3, 3]
# │    └─bn.weight                                                                             ├─1,024                   [1024]
# │    └─bn.bias                                                                               └─1,024                   [1024]
# │    └─Conv2d (conv): 2-27               [1, 512, 13, 13]          [1, 1024, 13, 13]         4,718,592                 [3, 3]                    797,442,048               True
# │    │    └─weight                                                                           └─4,718,592               [512, 1024, 3, 3]
# │    └─BatchNorm2d (bn): 2-28            [1, 1024, 13, 13]         [1, 1024, 13, 13]         2,048                     --                        2,048                     True
# │    │    └─weight                                                                           ├─1,024                   [1024]
# │    │    └─bias                                                                             └─1,024                   [1024]
# ├─Module (conv15): 1-20                  --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─524,288                 [512, 1024, 1, 1]
# │    └─bn.weight                                                                             ├─512                     [512]
# │    └─bn.bias                                                                               └─512                     [512]
# │    └─Conv2d (conv): 2-29               [1, 1024, 13, 13]         [1, 512, 13, 13]          524,288                   [1, 1]                    88,604,672                True
# │    │    └─weight                                                                           └─524,288                 [1024, 512, 1, 1]
# │    └─BatchNorm2d (bn): 2-30            [1, 512, 13, 13]          [1, 512, 13, 13]          1,024                     --                        1,024                     True
# │    │    └─weight                                                                           ├─512                     [512]
# │    │    └─bias                                                                             └─512                     [512]
# ├─Module (conv16): 1-21                  --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─4,718,592               [1024, 512, 3, 3]
# │    └─bn.weight                                                                             ├─1,024                   [1024]
# │    └─bn.bias                                                                               └─1,024                   [1024]
# │    └─Conv2d (conv): 2-31               [1, 512, 13, 13]          [1, 1024, 13, 13]         4,718,592                 [3, 3]                    797,442,048               True
# │    │    └─weight                                                                           └─4,718,592               [512, 1024, 3, 3]
# │    └─BatchNorm2d (bn): 2-32            [1, 1024, 13, 13]         [1, 1024, 13, 13]         2,048                     --                        2,048                     True
# │    │    └─weight                                                                           ├─1,024                   [1024]
# │    │    └─bias                                                                             └─1,024                   [1024]
# ├─Module (conv17): 1-22                  --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─524,288                 [512, 1024, 1, 1]
# │    └─bn.weight                                                                             ├─512                     [512]
# │    └─bn.bias                                                                               └─512                     [512]
# │    └─Conv2d (conv): 2-33               [1, 1024, 13, 13]         [1, 512, 13, 13]          524,288                   [1, 1]                    88,604,672                True
# │    │    └─weight                                                                           └─524,288                 [1024, 512, 1, 1]
# │    └─BatchNorm2d (bn): 2-34            [1, 512, 13, 13]          [1, 512, 13, 13]          1,024                     --                        1,024                     True
# │    │    └─weight                                                                           ├─512                     [512]
# │    │    └─bias                                                                             └─512                     [512]
# ├─Module (conv18): 1-23                  --                        --                        --                        --                        --                        True
# │    └─conv.weight                                                                           ├─4,718,592               [1024, 512, 3, 3]
# │    └─bn.weight                                                                             ├─1,024                   [1024]
# │    └─bn.bias                                                                               └─1,024                   [1024]
# │    └─Conv2d (conv): 2-35               [1, 512, 13, 13]          [1, 1024, 13, 13]         4,718,592                 [3, 3]                    797,442,048               True
# │    │    └─weight                                                                           └─4,718,592               [512, 1024, 3, 3]
# │    └─BatchNorm2d (bn): 2-36            [1, 1024, 13, 13]         [1, 1024, 13, 13]         2,048                     --                        2,048                     True
# │    │    └─weight                                                                           ├─1,024                   [1024]
# │    │    └─bias                                                                             └─1,024                   [1024]
# ==============================================================================================================================================================================================
# Total params: 19,817,376
# Trainable params: 19,817,376
# Non-trainable params: 0
# Total mult-adds (G): 9.45
# ==============================================================================================================================================================================================
# Input size (MB): 2.08
# Forward/backward pass size (MB): 249.20
# Params size (MB): 79.27
# Estimated Total Size (MB): 330.55
# ==============================================================================================================================================================================================

# %% [markdown]
# ## Inspect Results

# %%
from models.darknet19 import Darknet19Config, Darknet19

device = 'cuda'
from_ckpt = '../out/darknet19_imagenet2012/20240306-064919/ckpt_last.pt'

checkpoint = torch.load(from_ckpt, map_location='cpu')
checkpoint_model_args = checkpoint['model_args']
model_config = Darknet19Config(**checkpoint_model_args)
model = Darknet19(model_config)
state_dict = checkpoint['model']
model.load_state_dict(state_dict)
model = model.to(device)
model.eval()
# Out:
# number of parameters: 20.84M
# Darknet19(
#   (backbone): Darknet19Backbone(
#     (conv1): Darknet19Conv2d(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Darknet19Conv2d(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Darknet19Conv2d(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (conv4): Darknet19Conv2d(
#       (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (conv5): Darknet19Conv2d(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv6): Darknet19Conv2d(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (conv7): Darknet19Conv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (conv8): Darknet19Conv2d(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv9): Darknet19Conv2d(
#       (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (conv10): Darknet19Conv2d(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (conv11): Darknet19Conv2d(
#       (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (conv12): Darknet19Conv2d(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (conv13): Darknet19Conv2d(
#       (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (maxpool5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv14): Darknet19Conv2d(
#       (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(1024, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (conv15): Darknet19Conv2d(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (conv16): Darknet19Conv2d(
#       (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(1024, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (conv17): Darknet19Conv2d(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#     (conv18): Darknet19Conv2d(
#       (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(1024, eps=1e-06, momentum=0.01, affine=True, track_running_stats=True)
#     )
#   )
#   (head): Sequential(
#     (0): Conv2d(1024, 1000, kernel_size=(1, 1), stride=(1, 1))
#     (1): AdaptiveAvgPool2d(output_size=(1, 1))
#     (2): Flatten(start_dim=1, end_dim=-1)
#   )
# )

# %% [markdown]
# Modify the transform accordingly

# %%
from torch.utils.data.dataloader import DataLoader
import torchvision
from torchvision.transforms import v2

data_dir = '../data/imagenet2012'
img_h, img_w = checkpoint['config']['img_h'], checkpoint['config']['img_w']
imgs_mean = checkpoint['config']['imgs_mean']
imgs_std = checkpoint['config']['imgs_std']

dataset = torchvision.datasets.ImageNet(
    data_dir, split='val',
    transform=v2.Compose([
        v2.ToImage(),
        v2.Resize(size=max(img_h, img_w), #int(max(img_h, img_w) * 256 / 224),
                  #max_size=max(img_h, img_w) + 1,  # max_size must > size
                  antialias=True),
        v2.CenterCrop(size=(img_h, img_w)),
        v2.ToDtype(torch.float32, scale=True),
        v2.Normalize(mean=imgs_mean, std=imgs_std),
    ])
)
dataloader = DataLoader(dataset, batch_size=256, shuffle=False, num_workers=8, pin_memory=True)

# %%
from tqdm import tqdm

with torch.inference_mode():
    acc1, acc5 = 0.0, 0.0
    n_seen = 0
    for X, Y in tqdm(dataloader):
        if 'cuda' in device:
            X = X.to(device, non_blocking=True)
            Y = Y.to(device, non_blocking=True)
        else:
            X, Y = X.to(device), Y.to(device)
        logits, loss = model(X, Y)
        _, pred = logits.topk(5, 1, True, True)
        pred = pred.t()
        correct = pred.eq(Y.view(1, -1).expand_as(pred))
        n_seen += X.size(0)
        acc1 += correct[:1].reshape(-1).float().sum(0).item()
        acc5 += correct[:5].reshape(-1).float().sum(0).item()
    print(acc1, acc5)
    acc1 = 100 * acc1 / n_seen
    acc5 = 100 * acc5 / n_seen
    print(f"Top-1 accuracy: {acc1:.2f}%")
    print(f"Top-5 accuracy: {acc5:.2f}%")
# Out:
# 100%|██████████| 196/196 [00:19<00:00,  9.91it/s]
# 36588.0 45721.0
# Top-1 accuracy: 73.18%
# Top-5 accuracy: 91.44%

# %% [markdown]
# ### Results
#
# | Runs                                          | Acc1   | Acc5   | Duration |
# |-----------------------------------------------|--------|--------|----------|
# | 20240301-133108/ckpt_last.pt (overfit-no-aug) | 63.23% | 85.00% | 26.0s    |
# | 20240301-062829/ckpt_last.pt (simple-aug)     | 73.03% | 91.28% | 21.4s    |
# | 20240303-055517/ckpt_last.pt (448 simple-aug) | 75.88% | 93.01% | 1m0.2s   |
# | 20240306-064919/ckpt_last.pt (timm-aug)       | 73.18% | 91.44% | 25.7s    |
